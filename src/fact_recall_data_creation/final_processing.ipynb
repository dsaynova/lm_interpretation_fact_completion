# %% [markdown]
# # Final Processing
# For the creation of PrISM datasets with samples corresponding to exact fact recall and guesswork.

# %% [markdown]
# ## Set up enviroment

# %% [markdown]
# Make sure to stand in the root folder of the repo.

# %%
import os
os.chdir("../.")
os.getcwd()

# %%
import pandas as pd

# %% [markdown]
# ## Define paths and folder for storing results
#
# We create datasets for each of the analysed LMs. Make sure to specify the desired LM in the cell below. The notebook will then create the datasets with the exact fact recall and guesswork samples for that model.

# %%
MODEL_NAME = "llama2_13B" # "llama2_7B" #"gpt2_xl"
DATA_PATH = f"data/data_creation/{MODEL_NAME}/lama_data_preds_wiki_nb_pb.jsonl"
SAVEFOLDER = f"data/data_creation/{MODEL_NAME}"

# %% [markdown]
# ## Load the data

# %%
data = pd.read_json(DATA_PATH, lines=True)
data = data.drop(columns=["uuid", "obj_uri", "sub_uri"])
data = data.drop_duplicates()
data
# Out:
#         obj_label       sub_label predicate_id         source  \
# 0       Alexandra    Allan Peiper          P19       TREx_UHN
# 1       Alexandra    Allan Peiper          P19       TREx_UHN
# 2       Alexandra    Allan Peiper          P19       TREx_UHN
# 3       Alexandra    Allan Peiper          P19       TREx_UHN
# 4       Alexandra    Allan Peiper          P19       TREx_UHN
# ...           ...             ...          ...            ...
# 227788     Newark  Joshua Mathiot          P20  Google_RE_UHN
# 227789     Newark  Joshua Mathiot          P20  Google_RE_UHN
# 227790     Newark  Joshua Mathiot          P20  Google_RE_UHN
# 227791     Newark  Joshua Mathiot          P20  Google_RE_UHN
# 227792     Newark  Joshua Mathiot          P20  Google_RE_UHN
#
#                                  prompt                    template  \
# 0              Allan Peiper was born in         [X] was born in [Y]
# 1              Allan Peiper was born in         [X] was born in [Y]
# 2              Allan Peiper was born in         [X] was born in [Y]
# 3       Allan Peiper is originally from  [X] is originally from [Y]
# 4       Allan Peiper is originally from  [X] is originally from [Y]
# ...                                 ...                         ...
# 227788   Joshua Mathiot's life ended in     [X]'s life ended in [Y]
# 227789   Joshua Mathiot's life ended in     [X]'s life ended in [Y]
# 227790      Joshua Mathiot succumbed at        [X] succumbed at [Y]
# 227791      Joshua Mathiot succumbed at        [X] succumbed at [Y]
# 227792      Joshua Mathiot succumbed at        [X] succumbed at [Y]
#
#         sub_view_rates  obj_view_rates answers  p_answers  rank_answers  \
# 0           558.416667     6956.750000           0.274003             0
# 1           558.416667     6956.750000     New   0.044721             1
# 2           558.416667     6956.750000     the   0.037551             2
# 3           558.416667     6956.750000     the   0.092337             0
# 4           558.416667     6956.750000     New   0.045463             1
# ...                ...             ...     ...        ...           ...
# 227788      124.416667     2572.166667     the   0.115215             1
# 227789      124.416667     2572.166667           0.083683             2
# 227790      124.416667     2572.166667     the   0.378701             0
# 227791      124.416667     2572.166667           0.220430             1
# 227792      124.416667     2572.166667     age   0.177423             2
#
#         string_match  person_name           used_template  prompt_bias
# 0               True         True         [X] was born in         True
# 1              False        False         [X] was born in         True
# 2              False        False         [X] was born in         True
# 3              False        False  [X] is originally from         True
# 4              False        False  [X] is originally from         True
# ...              ...          ...                     ...          ...
# 227788         False        False     [X]'s life ended in         True
# 227789          True         True     [X]'s life ended in         True
# 227790         False        False        [X] succumbed at         True
# 227791          True         True        [X] succumbed at         True
# 227792         False        False        [X] succumbed at         True
#
# [227751 rows x 15 columns]

# %% [markdown]
# ## Add labels on correctness

# %%
data["strict_correct"] = data.apply(lambda row: row.answers.strip()==row.obj_label, axis=1)

# %%
data["first_token_correct"] = data.apply(lambda row: len(row.answers.strip())>=3 and row.obj_label.startswith(row.answers.strip()), axis=1)

# %%
data[(data.first_token_correct) & ~(data.strict_correct)]
# Out:
#         obj_label         sub_label predicate_id         source  \
# 105       Antwerp    Frans Floris I          P19       TREx_UHN
# 109       Antwerp    Frans Floris I          P19       TREx_UHN
# 111       Antwerp    Frans Floris I          P19       TREx_UHN
# 115       Antwerp    Frans Floris I          P19       TREx_UHN
# 119       Antwerp    Frans Floris I          P19       TREx_UHN
# ...           ...               ...          ...            ...
# 214786  Bucharest  George Georgescu          P20  Google_RE_UHN
# 214792  Bucharest  George Georgescu          P20  Google_RE_UHN
# 220906    Antwerp   Frans de Momper          P20  Google_RE_UHN
# 220912    Antwerp   Frans de Momper          P20  Google_RE_UHN
# 221416     Zagreb       Frane Bulić          P20  Google_RE_UHN
#
#                                     prompt                     template  \
# 105             Frans Floris I was born in          [X] was born in [Y]
# 109      Frans Floris I is originally from   [X] is originally from [Y]
# 111     Frans Floris I was originally from  [X] was originally from [Y]
# 115         Frans Floris I originated from      [X] originated from [Y]
# 119         Frans Floris I originates from      [X] originates from [Y]
# ...                                    ...                          ...
# 214786            George Georgescu died in              [X] died in [Y]
# 214792     George Georgescu passed away in       [X] passed away in [Y]
# 220906             Frans de Momper died in              [X] died in [Y]
# 220912      Frans de Momper passed away in       [X] passed away in [Y]
# 221416          Frane Bulić passed away in       [X] passed away in [Y]
#
#         sub_view_rates  obj_view_rates answers  p_answers  rank_answers  \
# 105                NaN    50520.750000     Ant   0.427150             0
# 109                NaN    50520.750000     Ant   0.199198             1
# 111                NaN    50520.750000     Ant   0.282292             0
# 115                NaN    50520.750000     Ant   0.218820             1
# 119                NaN    50520.750000     Ant   0.117836             2
# ...                ...             ...     ...        ...           ...
# 214786      222.000000    61623.833333    Buch   0.085521             1
# 214792      222.000000    61623.833333    Buch   0.084553             1
# 220906      189.916667    50520.750000     Ant   0.056253             1
# 220912      189.916667    50520.750000     Ant   0.076051             1
# 221416      130.083333    41499.750000     Zag   0.175367             1
#
#         string_match  person_name            used_template  prompt_bias  \
# 105            False        False          [X] was born in        False
# 109            False        False   [X] is originally from        False
# 111            False        False  [X] was originally from        False
# 115            False        False      [X] originated from        False
# 119            False        False      [X] originates from        False
# ...              ...          ...                      ...          ...
# 214786         False         True              [X] died in        False
# 214792         False         True       [X] passed away in        False
# 220906         False        False              [X] died in        False
# 220912         False        False       [X] passed away in        False
# 221416         False        False       [X] passed away in        False
#
#         strict_correct  first_token_correct
# 105              False                 True
# 109              False                 True
# 111              False                 True
# 115              False                 True
# 119              False                 True
# ...                ...                  ...
# 214786           False                 True
# 214792           False                 True
# 220906           False                 True
# 220912           False                 True
# 221416           False                 True
#
# [718 rows x 17 columns]

# %%
data["correct"] = data["first_token_correct"]

# %% [markdown]
# ## Make data compatible with CT code
#
# The CT code expects some specific columns to exist in the dataset.

# %%
# add this for compatibility with the CT code
if MODEL_NAME == "llama2_7B" or MODEL_NAME == "llama2_13B":
    data["candidate_prediction"] = data["answers"]
    data["subject"] = data["sub_label"]
    data["known_id"] = data.index

# %% [markdown]
# ## Create data splits
#
# Before we can identify the exact fact recall and guesswork samples, we need to add some necessary metadata on biases and consistency.

# %% [markdown]
# ### Add necessary metadata

# %%
data["surface_pred"] = data.apply(lambda row: any(row[["string_match", "person_name", "prompt_bias"]]), axis=1)
print(f"{sum(data['surface_pred'])} model predictions out of {len(data)} are potential surface level predictions")
# Out:
# 192978 model predictions out of 227751 are potential surface level predictions

# %% [markdown]
# We use model confidence proxied by consistency to paraphrasing to identify exact fact recall samples.

# %%
CONSISTENCY_THRESH = 5

# count surface level preds and non surface level preds separately
consistency_counts = data.groupby(["predicate_id", "sub_label", "obj_label", "answers", "surface_pred"]).p_answers.count().rename("cons_counts")
data["consistency_counts"] = data.apply(lambda row: consistency_counts[row.predicate_id, row.sub_label, row.obj_label, row.answers, row.surface_pred], axis=1)
data.head()
# Out:
#    obj_label     sub_label predicate_id    source  \
# 0  Alexandra  Allan Peiper          P19  TREx_UHN
# 1  Alexandra  Allan Peiper          P19  TREx_UHN
# 2  Alexandra  Allan Peiper          P19  TREx_UHN
# 3  Alexandra  Allan Peiper          P19  TREx_UHN
# 4  Alexandra  Allan Peiper          P19  TREx_UHN
#
#                             prompt                    template  \
# 0         Allan Peiper was born in         [X] was born in [Y]
# 1         Allan Peiper was born in         [X] was born in [Y]
# 2         Allan Peiper was born in         [X] was born in [Y]
# 3  Allan Peiper is originally from  [X] is originally from [Y]
# 4  Allan Peiper is originally from  [X] is originally from [Y]
#
#    sub_view_rates  obj_view_rates answers  p_answers  rank_answers  \
# 0      558.416667         6956.75           0.274003             0
# 1      558.416667         6956.75     New   0.044721             1
# 2      558.416667         6956.75     the   0.037551             2
# 3      558.416667         6956.75     the   0.092337             0
# 4      558.416667         6956.75     New   0.045463             1
#
#    string_match  person_name           used_template  prompt_bias  \
# 0          True         True         [X] was born in         True
# 1         False        False         [X] was born in         True
# 2         False        False         [X] was born in         True
# 3         False        False  [X] is originally from         True
# 4         False        False  [X] is originally from         True
#
#    strict_correct  first_token_correct  correct  surface_pred  \
# 0           False                False    False          True
# 1           False                False    False          True
# 2           False                False    False          True
# 3           False                False    False          True
# 4           False                False    False          True
#
#    consistency_counts
# 0                   1
# 1                   3
# 2                   5
# 3                   5
# 4                   3

# %%
data["confident"] = data.consistency_counts>CONSISTENCY_THRESH
confident_fact_recall_preds = data[data.confident & ~(data.surface_pred) & data.correct].copy()

confident_fact_recall_preds
# Out:
#         obj_label      sub_label predicate_id         source  \
# 12391   Melbourne  Edward Duyker          P19       TREx_UHN
# 12393   Melbourne  Edward Duyker          P19       TREx_UHN
# 12397   Melbourne  Edward Duyker          P19       TREx_UHN
# 12401   Melbourne  Edward Duyker          P19       TREx_UHN
# 12404   Melbourne  Edward Duyker          P19       TREx_UHN
# ...           ...            ...          ...            ...
# 191350  Melbourne  Edward Duyker          P19  Google_RE_UHN
# 191352  Melbourne  Edward Duyker          P19  Google_RE_UHN
# 191356  Melbourne  Edward Duyker          P19  Google_RE_UHN
# 191360  Melbourne  Edward Duyker          P19  Google_RE_UHN
# 191363  Melbourne  Edward Duyker          P19  Google_RE_UHN
#
#                                    prompt                     template  \
# 12391           Edward Duyker was born in          [X] was born in [Y]
# 12393    Edward Duyker is originally from   [X] is originally from [Y]
# 12397   Edward Duyker was originally from  [X] was originally from [Y]
# 12401       Edward Duyker originated from      [X] originated from [Y]
# 12404       Edward Duyker originates from      [X] originates from [Y]
# ...                                   ...                          ...
# 191350          Edward Duyker was born in          [X] was born in [Y]
# 191352   Edward Duyker is originally from   [X] is originally from [Y]
# 191356  Edward Duyker was originally from  [X] was originally from [Y]
# 191360      Edward Duyker originated from      [X] originated from [Y]
# 191363      Edward Duyker originates from      [X] originates from [Y]
#
#         sub_view_rates  obj_view_rates     answers  p_answers  ...  \
# 12391       320.416667   124325.083333   Melbourne   0.176117  ...
# 12393       320.416667   124325.083333   Melbourne   0.137194  ...
# 12397       320.416667   124325.083333   Melbourne   0.072961  ...
# 12401       320.416667   124325.083333   Melbourne   0.035770  ...
# 12404       320.416667   124325.083333   Melbourne   0.077432  ...
# ...                ...             ...         ...        ...  ...
# 191350      320.416667   124325.083333   Melbourne   0.176117  ...
# 191352      320.416667   124325.083333   Melbourne   0.137194  ...
# 191356      320.416667   124325.083333   Melbourne   0.072961  ...
# 191360      320.416667   124325.083333   Melbourne   0.035770  ...
# 191363      320.416667   124325.083333   Melbourne   0.077432  ...
#
#         string_match  person_name            used_template prompt_bias  \
# 12391          False        False          [X] was born in       False
# 12393          False        False   [X] is originally from       False
# 12397          False        False  [X] was originally from       False
# 12401          False        False      [X] originated from       False
# 12404          False        False      [X] originates from       False
# ...              ...          ...                      ...         ...
# 191350         False        False          [X] was born in       False
# 191352         False        False   [X] is originally from       False
# 191356         False        False  [X] was originally from       False
# 191360         False        False      [X] originated from       False
# 191363         False        False      [X] originates from       False
#
#         strict_correct  first_token_correct  correct  surface_pred  \
# 12391             True                 True     True         False
# 12393             True                 True     True         False
# 12397             True                 True     True         False
# 12401             True                 True     True         False
# 12404             True                 True     True         False
# ...                ...                  ...      ...           ...
# 191350            True                 True     True         False
# 191352            True                 True     True         False
# 191356            True                 True     True         False
# 191360            True                 True     True         False
# 191363            True                 True     True         False
#
#         consistency_counts  confident
# 12391                   10       True
# 12393                   10       True
# 12397                   10       True
# 12401                   10       True
# 12404                   10       True
# ...                    ...        ...
# 191350                  10       True
# 191352                  10       True
# 191356                  10       True
# 191360                  10       True
# 191363                  10       True
#
# [3845 rows x 21 columns]

# %% [markdown]
# Our bias filter is not perfect?

# %%
confident_fact_recall_preds[confident_fact_recall_preds.sub_view_rates<1000].groupby(["obj_label","sub_label","predicate_id","answers"]).mean()
# Out:
#                                                                          sub_view_rates  \
# obj_label   sub_label                         predicate_id answers
# Australia   Sydney Twelve                     P495          Australia        285.750000
#             The Early Bird Show               P495          Australia        542.750000
# Barcelona   Institut d'Estudis Catalans       P740          Barcelona        775.416667
# Brazil      Bicho de Sete Cabeças             P495          Brazil           235.500000
#             Desejos de Mulher                 P495          Brazil           287.833333
#             Mulheres de Areia                 P495          Brazil           766.083333
#             O Quatrilho                       P495          Brazil           623.416667
# Cuba        Suite Habana                      P495          Cuba             278.166667
# Denmark     Lise Ringheim                     P27           Denmark           88.416667
# Egypt       Ayyam El Sadat                    P495          Egypt            154.583333
# England     association football              P495          England           49.416667
# Finland     Suomen Kuvalehti                  P495          Finland          338.500000
# Florence    Salvatore Ferragamo Italia S.p.A. P740          Florence         389.250000
# Indonesia   Evan Dimas Darmono                P27           Indonesia         66.583333
# Ireland     John Banim                        P27           Ireland          354.500000
#             Robert Erskine Childers           P27           Ireland          707.833333
# Italy       Lupo Alberto                      P495          Italy            402.916667
#             The Mattei Affair                 P495          Italy            892.416667
# Jamaica     reggae                            P495          Jamaica            9.166667
# Japan       Bandai Channel                    P740          Japan            342.416667
#             Genma Taisen                      P495          Japan            869.583333
#             Great Dangaioh                    P495          Japan            576.083333
#             Magne Robo Gakeen                 P495          Japan            490.583333
#             Mezamashi TV                      P495          Japan            468.000000
#             Sonic Soldier Borgman             P495          Japan            650.416667
#             matcha                            P495          Japan              4.416667
# Mexico      La Hija del Jardinero             P495          Mexico           821.583333
# Michigan    Lansing                           P1376         Michigan         926.750000
# Moldova     Vasile Stati                      P27           Mold             205.250000
# Norway      Bukkene Bruse                     P495          Norway           262.750000
#             Dagsavisen                        P495          Norway           482.250000
# Poland      Bezimienni bohaterowie            P495          Poland           108.000000
#             Brzydula                          P495          Poland           409.416667
#             Newsweek Polska                   P495          Poland           480.416667
#             Polityka                          P495          Poland           732.666667
#             Prokurator Alicja Horn            P495          Poland           100.166667
#             Taniec z gwiazdami                P495          Poland           378.500000
# Shanghai    Mingxing Film Company             P740          Shanghai         170.333333
# Singapore   Howe Yoon Chong                   P27           Singapore        430.666667
# Spain       Lucas de Tuy                      P27           Spain            169.583333
# Sweden      Nyhetsmorgon                      P495          Sweden           381.500000
#             Sven-Ingvars                      P495          Sweden           696.250000
#             Uppdrag granskning                P495          Sweden           413.000000
# Switzerland Auguste Forel                     P27           Switzerland      761.333333
# Wales       Y Cymro                           P495          Wales            469.416667
# Zimbabwe    Patrick Chinamasa                 P27           Zimbabwe         758.166667
# chemistry   Italian Chemical Society          P101          chemistry        180.083333
#
#                                                                          obj_view_rates  \
# obj_label   sub_label                         predicate_id answers
# Australia   Sydney Twelve                     P495          Australia     576541.583333
#             The Early Bird Show               P495          Australia     576541.583333
# Barcelona   Institut d'Estudis Catalans       P740          Barcelona     156304.833333
# Brazil      Bicho de Sete Cabeças             P495          Brazil        326610.333333
#             Desejos de Mulher                 P495          Brazil        326610.333333
#             Mulheres de Areia                 P495          Brazil        326610.333333
#             O Quatrilho                       P495          Brazil        326610.333333
# Cuba        Suite Habana                      P495          Cuba          193325.916667
# Denmark     Lise Ringheim                     P27           Denmark       259110.416667
# Egypt       Ayyam El Sadat                    P495          Egypt         252156.833333
# England     association football              P495          England       344100.833333
# Finland     Suomen Kuvalehti                  P495          Finland       236600.416667
# Florence    Salvatore Ferragamo Italia S.p.A. P740          Florence       87461.500000
# Indonesia   Evan Dimas Darmono                P27           Indonesia     336610.250000
# Ireland     John Banim                        P27           Ireland       269795.166667
#             Robert Erskine Childers           P27           Ireland       269795.166667
# Italy       Lupo Alberto                      P495          Italy         338858.666667
#             The Mattei Affair                 P495          Italy         338858.666667
# Jamaica     reggae                            P495          Jamaica       180541.250000
# Japan       Bandai Channel                    P740          Japan         491464.833333
#             Genma Taisen                      P495          Japan         491464.833333
#             Great Dangaioh                    P495          Japan         491464.833333
#             Magne Robo Gakeen                 P495          Japan         491464.833333
#             Mezamashi TV                      P495          Japan         491464.833333
#             Sonic Soldier Borgman             P495          Japan         491464.833333
#             matcha                            P495          Japan         491464.833333
# Mexico      La Hija del Jardinero             P495          Mexico        320825.333333
# Michigan    Lansing                           P1376         Michigan      126022.000000
# Moldova     Vasile Stati                      P27           Mold          151127.333333
# Norway      Bukkene Bruse                     P495          Norway        273060.500000
#             Dagsavisen                        P495          Norway        273060.500000
# Poland      Bezimienni bohaterowie            P495          Poland        277818.750000
#             Brzydula                          P495          Poland        277818.750000
#             Newsweek Polska                   P495          Poland        277818.750000
#             Polityka                          P495          Poland        277818.750000
#             Prokurator Alicja Horn            P495          Poland        277818.750000
#             Taniec z gwiazdami                P495          Poland        277818.750000
# Shanghai    Mingxing Film Company             P740          Shanghai      132321.333333
# Singapore   Howe Yoon Chong                   P27           Singapore     536193.500000
# Spain       Lucas de Tuy                      P27           Spain         321776.166667
# Sweden      Nyhetsmorgon                      P495          Sweden        309365.750000
#             Sven-Ingvars                      P495          Sweden        309365.750000
#             Uppdrag granskning                P495          Sweden        309365.750000
# Switzerland Auguste Forel                     P27           Switzerland   338587.666667
# Wales       Y Cymro                           P495          Wales         208236.750000
# Zimbabwe    Patrick Chinamasa                 P27           Zimbabwe      150796.666667
# chemistry   Italian Chemical Society          P101          chemistry      77810.000000
#
#                                                                          p_answers  \
# obj_label   sub_label                         predicate_id answers
# Australia   Sydney Twelve                     P495          Australia     0.065553
#             The Early Bird Show               P495          Australia     0.064941
# Barcelona   Institut d'Estudis Catalans       P740          Barcelona     0.049500
# Brazil      Bicho de Sete Cabeças             P495          Brazil        0.043110
#             Desejos de Mulher                 P495          Brazil        0.077602
#             Mulheres de Areia                 P495          Brazil        0.060944
#             O Quatrilho                       P495          Brazil        0.053229
# Cuba        Suite Habana                      P495          Cuba          0.054528
# Denmark     Lise Ringheim                     P27           Denmark       0.113276
# Egypt       Ayyam El Sadat                    P495          Egypt         0.085481
# England     association football              P495          England       0.100718
# Finland     Suomen Kuvalehti                  P495          Finland       0.099638
# Florence    Salvatore Ferragamo Italia S.p.A. P740          Florence      0.102172
# Indonesia   Evan Dimas Darmono                P27           Indonesia     0.130387
# Ireland     John Banim                        P27           Ireland       0.142484
#             Robert Erskine Childers           P27           Ireland       0.063509
# Italy       Lupo Alberto                      P495          Italy         0.049154
#             The Mattei Affair                 P495          Italy         0.052681
# Jamaica     reggae                            P495          Jamaica       0.121064
# Japan       Bandai Channel                    P740          Japan         0.060161
#             Genma Taisen                      P495          Japan         0.062417
#             Great Dangaioh                    P495          Japan         0.086254
#             Magne Robo Gakeen                 P495          Japan         0.123535
#             Mezamashi TV                      P495          Japan         0.072312
#             Sonic Soldier Borgman             P495          Japan         0.068780
#             matcha                            P495          Japan         0.151664
# Mexico      La Hija del Jardinero             P495          Mexico        0.044243
# Michigan    Lansing                           P1376         Michigan      0.591171
# Moldova     Vasile Stati                      P27           Mold          0.093975
# Norway      Bukkene Bruse                     P495          Norway        0.056768
#             Dagsavisen                        P495          Norway        0.066606
# Poland      Bezimienni bohaterowie            P495          Poland        0.066380
#             Brzydula                          P495          Poland        0.064710
#             Newsweek Polska                   P495          Poland        0.094041
#             Polityka                          P495          Poland        0.084917
#             Prokurator Alicja Horn            P495          Poland        0.057085
#             Taniec z gwiazdami                P495          Poland        0.080656
# Shanghai    Mingxing Film Company             P740          Shanghai      0.048393
# Singapore   Howe Yoon Chong                   P27           Singapore     0.116222
# Spain       Lucas de Tuy                      P27           Spain         0.053410
# Sweden      Nyhetsmorgon                      P495          Sweden        0.072202
#             Sven-Ingvars                      P495          Sweden        0.049228
#             Uppdrag granskning                P495          Sweden        0.285571
# Switzerland Auguste Forel                     P27           Switzerland   0.103260
# Wales       Y Cymro                           P495          Wales         0.064403
# Zimbabwe    Patrick Chinamasa                 P27           Zimbabwe      0.082684
# chemistry   Italian Chemical Society          P101          chemistry     0.104127
#
#                                                                          rank_answers  \
# obj_label   sub_label                         predicate_id answers
# Australia   Sydney Twelve                     P495          Australia        1.500000
#             The Early Bird Show               P495          Australia        1.000000
# Barcelona   Institut d'Estudis Catalans       P740          Barcelona        1.000000
# Brazil      Bicho de Sete Cabeças             P495          Brazil           1.500000
#             Desejos de Mulher                 P495          Brazil           1.000000
#             Mulheres de Areia                 P495          Brazil           1.333333
#             O Quatrilho                       P495          Brazil           1.571429
# Cuba        Suite Habana                      P495          Cuba             1.500000
# Denmark     Lise Ringheim                     P27           Denmark          1.833333
# Egypt       Ayyam El Sadat                    P495          Egypt            1.062500
# England     association football              P495          England          1.000000
# Finland     Suomen Kuvalehti                  P495          Finland          1.333333
# Florence    Salvatore Ferragamo Italia S.p.A. P740          Florence         0.857143
# Indonesia   Evan Dimas Darmono                P27           Indonesia        1.000000
# Ireland     John Banim                        P27           Ireland          1.000000
#             Robert Erskine Childers           P27           Ireland          1.428571
# Italy       Lupo Alberto                      P495          Italy            1.285714
#             The Mattei Affair                 P495          Italy            1.555556
# Jamaica     reggae                            P495          Jamaica          0.888889
# Japan       Bandai Channel                    P740          Japan            0.375000
#             Genma Taisen                      P495          Japan            0.625000
#             Great Dangaioh                    P495          Japan            1.000000
#             Magne Robo Gakeen                 P495          Japan            1.000000
#             Mezamashi TV                      P495          Japan            1.166667
#             Sonic Soldier Borgman             P495          Japan            1.333333
#             matcha                            P495          Japan            0.900000
# Mexico      La Hija del Jardinero             P495          Mexico           1.428571
# Michigan    Lansing                           P1376         Michigan         0.000000
# Moldova     Vasile Stati                      P27           Mold             1.500000
# Norway      Bukkene Bruse                     P495          Norway           1.250000
#             Dagsavisen                        P495          Norway           0.833333
# Poland      Bezimienni bohaterowie            P495          Poland           1.333333
#             Brzydula                          P495          Poland           1.285714
#             Newsweek Polska                   P495          Poland           1.083333
#             Polityka                          P495          Poland           1.375000
#             Prokurator Alicja Horn            P495          Poland           1.333333
#             Taniec z gwiazdami                P495          Poland           1.272727
# Shanghai    Mingxing Film Company             P740          Shanghai         1.000000
# Singapore   Howe Yoon Chong                   P27           Singapore        1.333333
# Spain       Lucas de Tuy                      P27           Spain            1.500000
# Sweden      Nyhetsmorgon                      P495          Sweden           1.285714
#             Sven-Ingvars                      P495          Sweden           1.142857
#             Uppdrag granskning                P495          Sweden           0.444444
# Switzerland Auguste Forel                     P27           Switzerland      1.833333
# Wales       Y Cymro                           P495          Wales            1.333333
# Zimbabwe    Patrick Chinamasa                 P27           Zimbabwe         2.000000
# chemistry   Italian Chemical Society          P101          chemistry        1.000000
#
#                                                                          string_match  \
# obj_label   sub_label                         predicate_id answers
# Australia   Sydney Twelve                     P495          Australia           False
#             The Early Bird Show               P495          Australia           False
# Barcelona   Institut d'Estudis Catalans       P740          Barcelona           False
# Brazil      Bicho de Sete Cabeças             P495          Brazil              False
#             Desejos de Mulher                 P495          Brazil              False
#             Mulheres de Areia                 P495          Brazil              False
#             O Quatrilho                       P495          Brazil              False
# Cuba        Suite Habana                      P495          Cuba                False
# Denmark     Lise Ringheim                     P27           Denmark             False
# Egypt       Ayyam El Sadat                    P495          Egypt               False
# England     association football              P495          England             False
# Finland     Suomen Kuvalehti                  P495          Finland             False
# Florence    Salvatore Ferragamo Italia S.p.A. P740          Florence            False
# Indonesia   Evan Dimas Darmono                P27           Indonesia           False
# Ireland     John Banim                        P27           Ireland             False
#             Robert Erskine Childers           P27           Ireland             False
# Italy       Lupo Alberto                      P495          Italy               False
#             The Mattei Affair                 P495          Italy               False
# Jamaica     reggae                            P495          Jamaica             False
# Japan       Bandai Channel                    P740          Japan               False
#             Genma Taisen                      P495          Japan               False
#             Great Dangaioh                    P495          Japan               False
#             Magne Robo Gakeen                 P495          Japan               False
#             Mezamashi TV                      P495          Japan               False
#             Sonic Soldier Borgman             P495          Japan               False
#             matcha                            P495          Japan               False
# Mexico      La Hija del Jardinero             P495          Mexico              False
# Michigan    Lansing                           P1376         Michigan            False
# Moldova     Vasile Stati                      P27           Mold                False
# Norway      Bukkene Bruse                     P495          Norway              False
#             Dagsavisen                        P495          Norway              False
# Poland      Bezimienni bohaterowie            P495          Poland              False
#             Brzydula                          P495          Poland              False
#             Newsweek Polska                   P495          Poland              False
#             Polityka                          P495          Poland              False
#             Prokurator Alicja Horn            P495          Poland              False
#             Taniec z gwiazdami                P495          Poland              False
# Shanghai    Mingxing Film Company             P740          Shanghai            False
# Singapore   Howe Yoon Chong                   P27           Singapore           False
# Spain       Lucas de Tuy                      P27           Spain               False
# Sweden      Nyhetsmorgon                      P495          Sweden              False
#             Sven-Ingvars                      P495          Sweden              False
#             Uppdrag granskning                P495          Sweden              False
# Switzerland Auguste Forel                     P27           Switzerland         False
# Wales       Y Cymro                           P495          Wales               False
# Zimbabwe    Patrick Chinamasa                 P27           Zimbabwe            False
# chemistry   Italian Chemical Society          P101          chemistry           False
#
#                                                                          person_name  \
# obj_label   sub_label                         predicate_id answers
# Australia   Sydney Twelve                     P495          Australia          False
#             The Early Bird Show               P495          Australia          False
# Barcelona   Institut d'Estudis Catalans       P740          Barcelona          False
# Brazil      Bicho de Sete Cabeças             P495          Brazil             False
#             Desejos de Mulher                 P495          Brazil             False
#             Mulheres de Areia                 P495          Brazil             False
#             O Quatrilho                       P495          Brazil             False
# Cuba        Suite Habana                      P495          Cuba               False
# Denmark     Lise Ringheim                     P27           Denmark            False
# Egypt       Ayyam El Sadat                    P495          Egypt              False
# England     association football              P495          England            False
# Finland     Suomen Kuvalehti                  P495          Finland            False
# Florence    Salvatore Ferragamo Italia S.p.A. P740          Florence           False
# Indonesia   Evan Dimas Darmono                P27           Indonesia          False
# Ireland     John Banim                        P27           Ireland            False
#             Robert Erskine Childers           P27           Ireland            False
# Italy       Lupo Alberto                      P495          Italy              False
#             The Mattei Affair                 P495          Italy              False
# Jamaica     reggae                            P495          Jamaica            False
# Japan       Bandai Channel                    P740          Japan              False
#             Genma Taisen                      P495          Japan              False
#             Great Dangaioh                    P495          Japan              False
#             Magne Robo Gakeen                 P495          Japan              False
#             Mezamashi TV                      P495          Japan              False
#             Sonic Soldier Borgman             P495          Japan              False
#             matcha                            P495          Japan              False
# Mexico      La Hija del Jardinero             P495          Mexico             False
# Michigan    Lansing                           P1376         Michigan           False
# Moldova     Vasile Stati                      P27           Mold               False
# Norway      Bukkene Bruse                     P495          Norway             False
#             Dagsavisen                        P495          Norway             False
# Poland      Bezimienni bohaterowie            P495          Poland             False
#             Brzydula                          P495          Poland             False
#             Newsweek Polska                   P495          Poland             False
#             Polityka                          P495          Poland             False
#             Prokurator Alicja Horn            P495          Poland             False
#             Taniec z gwiazdami                P495          Poland             False
# Shanghai    Mingxing Film Company             P740          Shanghai           False
# Singapore   Howe Yoon Chong                   P27           Singapore          False
# Spain       Lucas de Tuy                      P27           Spain              False
# Sweden      Nyhetsmorgon                      P495          Sweden             False
#             Sven-Ingvars                      P495          Sweden             False
#             Uppdrag granskning                P495          Sweden             False
# Switzerland Auguste Forel                     P27           Switzerland        False
# Wales       Y Cymro                           P495          Wales              False
# Zimbabwe    Patrick Chinamasa                 P27           Zimbabwe           False
# chemistry   Italian Chemical Society          P101          chemistry          False
#
#                                                                          prompt_bias  \
# obj_label   sub_label                         predicate_id answers
# Australia   Sydney Twelve                     P495          Australia          False
#             The Early Bird Show               P495          Australia          False
# Barcelona   Institut d'Estudis Catalans       P740          Barcelona          False
# Brazil      Bicho de Sete Cabeças             P495          Brazil             False
#             Desejos de Mulher                 P495          Brazil             False
#             Mulheres de Areia                 P495          Brazil             False
#             O Quatrilho                       P495          Brazil             False
# Cuba        Suite Habana                      P495          Cuba               False
# Denmark     Lise Ringheim                     P27           Denmark            False
# Egypt       Ayyam El Sadat                    P495          Egypt              False
# England     association football              P495          England            False
# Finland     Suomen Kuvalehti                  P495          Finland            False
# Florence    Salvatore Ferragamo Italia S.p.A. P740          Florence           False
# Indonesia   Evan Dimas Darmono                P27           Indonesia          False
# Ireland     John Banim                        P27           Ireland            False
#             Robert Erskine Childers           P27           Ireland            False
# Italy       Lupo Alberto                      P495          Italy              False
#             The Mattei Affair                 P495          Italy              False
# Jamaica     reggae                            P495          Jamaica            False
# Japan       Bandai Channel                    P740          Japan              False
#             Genma Taisen                      P495          Japan              False
#             Great Dangaioh                    P495          Japan              False
#             Magne Robo Gakeen                 P495          Japan              False
#             Mezamashi TV                      P495          Japan              False
#             Sonic Soldier Borgman             P495          Japan              False
#             matcha                            P495          Japan              False
# Mexico      La Hija del Jardinero             P495          Mexico             False
# Michigan    Lansing                           P1376         Michigan           False
# Moldova     Vasile Stati                      P27           Mold               False
# Norway      Bukkene Bruse                     P495          Norway             False
#             Dagsavisen                        P495          Norway             False
# Poland      Bezimienni bohaterowie            P495          Poland             False
#             Brzydula                          P495          Poland             False
#             Newsweek Polska                   P495          Poland             False
#             Polityka                          P495          Poland             False
#             Prokurator Alicja Horn            P495          Poland             False
#             Taniec z gwiazdami                P495          Poland             False
# Shanghai    Mingxing Film Company             P740          Shanghai           False
# Singapore   Howe Yoon Chong                   P27           Singapore          False
# Spain       Lucas de Tuy                      P27           Spain              False
# Sweden      Nyhetsmorgon                      P495          Sweden             False
#             Sven-Ingvars                      P495          Sweden             False
#             Uppdrag granskning                P495          Sweden             False
# Switzerland Auguste Forel                     P27           Switzerland        False
# Wales       Y Cymro                           P495          Wales              False
# Zimbabwe    Patrick Chinamasa                 P27           Zimbabwe           False
# chemistry   Italian Chemical Society          P101          chemistry          False
#
#                                                                          strict_correct  \
# obj_label   sub_label                         predicate_id answers
# Australia   Sydney Twelve                     P495          Australia              True
#             The Early Bird Show               P495          Australia              True
# Barcelona   Institut d'Estudis Catalans       P740          Barcelona              True
# Brazil      Bicho de Sete Cabeças             P495          Brazil                 True
#             Desejos de Mulher                 P495          Brazil                 True
#             Mulheres de Areia                 P495          Brazil                 True
#             O Quatrilho                       P495          Brazil                 True
# Cuba        Suite Habana                      P495          Cuba                   True
# Denmark     Lise Ringheim                     P27           Denmark                True
# Egypt       Ayyam El Sadat                    P495          Egypt                  True
# England     association football              P495          England                True
# Finland     Suomen Kuvalehti                  P495          Finland                True
# Florence    Salvatore Ferragamo Italia S.p.A. P740          Florence               True
# Indonesia   Evan Dimas Darmono                P27           Indonesia              True
# Ireland     John Banim                        P27           Ireland                True
#             Robert Erskine Childers           P27           Ireland                True
# Italy       Lupo Alberto                      P495          Italy                  True
#             The Mattei Affair                 P495          Italy                  True
# Jamaica     reggae                            P495          Jamaica                True
# Japan       Bandai Channel                    P740          Japan                  True
#             Genma Taisen                      P495          Japan                  True
#             Great Dangaioh                    P495          Japan                  True
#             Magne Robo Gakeen                 P495          Japan                  True
#             Mezamashi TV                      P495          Japan                  True
#             Sonic Soldier Borgman             P495          Japan                  True
#             matcha                            P495          Japan                  True
# Mexico      La Hija del Jardinero             P495          Mexico                 True
# Michigan    Lansing                           P1376         Michigan               True
# Moldova     Vasile Stati                      P27           Mold                  False
# Norway      Bukkene Bruse                     P495          Norway                 True
#             Dagsavisen                        P495          Norway                 True
# Poland      Bezimienni bohaterowie            P495          Poland                 True
#             Brzydula                          P495          Poland                 True
#             Newsweek Polska                   P495          Poland                 True
#             Polityka                          P495          Poland                 True
#             Prokurator Alicja Horn            P495          Poland                 True
#             Taniec z gwiazdami                P495          Poland                 True
# Shanghai    Mingxing Film Company             P740          Shanghai               True
# Singapore   Howe Yoon Chong                   P27           Singapore              True
# Spain       Lucas de Tuy                      P27           Spain                  True
# Sweden      Nyhetsmorgon                      P495          Sweden                 True
#             Sven-Ingvars                      P495          Sweden                 True
#             Uppdrag granskning                P495          Sweden                 True
# Switzerland Auguste Forel                     P27           Switzerland            True
# Wales       Y Cymro                           P495          Wales                  True
# Zimbabwe    Patrick Chinamasa                 P27           Zimbabwe               True
# chemistry   Italian Chemical Society          P101          chemistry              True
#
#                                                                          first_token_correct  \
# obj_label   sub_label                         predicate_id answers
# Australia   Sydney Twelve                     P495          Australia                   True
#             The Early Bird Show               P495          Australia                   True
# Barcelona   Institut d'Estudis Catalans       P740          Barcelona                   True
# Brazil      Bicho de Sete Cabeças             P495          Brazil                      True
#             Desejos de Mulher                 P495          Brazil                      True
#             Mulheres de Areia                 P495          Brazil                      True
#             O Quatrilho                       P495          Brazil                      True
# Cuba        Suite Habana                      P495          Cuba                        True
# Denmark     Lise Ringheim                     P27           Denmark                     True
# Egypt       Ayyam El Sadat                    P495          Egypt                       True
# England     association football              P495          England                     True
# Finland     Suomen Kuvalehti                  P495          Finland                     True
# Florence    Salvatore Ferragamo Italia S.p.A. P740          Florence                    True
# Indonesia   Evan Dimas Darmono                P27           Indonesia                   True
# Ireland     John Banim                        P27           Ireland                     True
#             Robert Erskine Childers           P27           Ireland                     True
# Italy       Lupo Alberto                      P495          Italy                       True
#             The Mattei Affair                 P495          Italy                       True
# Jamaica     reggae                            P495          Jamaica                     True
# Japan       Bandai Channel                    P740          Japan                       True
#             Genma Taisen                      P495          Japan                       True
#             Great Dangaioh                    P495          Japan                       True
#             Magne Robo Gakeen                 P495          Japan                       True
#             Mezamashi TV                      P495          Japan                       True
#             Sonic Soldier Borgman             P495          Japan                       True
#             matcha                            P495          Japan                       True
# Mexico      La Hija del Jardinero             P495          Mexico                      True
# Michigan    Lansing                           P1376         Michigan                    True
# Moldova     Vasile Stati                      P27           Mold                        True
# Norway      Bukkene Bruse                     P495          Norway                      True
#             Dagsavisen                        P495          Norway                      True
# Poland      Bezimienni bohaterowie            P495          Poland                      True
#             Brzydula                          P495          Poland                      True
#             Newsweek Polska                   P495          Poland                      True
#             Polityka                          P495          Poland                      True
#             Prokurator Alicja Horn            P495          Poland                      True
#             Taniec z gwiazdami                P495          Poland                      True
# Shanghai    Mingxing Film Company             P740          Shanghai                    True
# Singapore   Howe Yoon Chong                   P27           Singapore                   True
# Spain       Lucas de Tuy                      P27           Spain                       True
# Sweden      Nyhetsmorgon                      P495          Sweden                      True
#             Sven-Ingvars                      P495          Sweden                      True
#             Uppdrag granskning                P495          Sweden                      True
# Switzerland Auguste Forel                     P27           Switzerland                 True
# Wales       Y Cymro                           P495          Wales                       True
# Zimbabwe    Patrick Chinamasa                 P27           Zimbabwe                    True
# chemistry   Italian Chemical Society          P101          chemistry                   True
#
#                                                                          correct  \
# obj_label   sub_label                         predicate_id answers
# Australia   Sydney Twelve                     P495          Australia       True
#             The Early Bird Show               P495          Australia       True
# Barcelona   Institut d'Estudis Catalans       P740          Barcelona       True
# Brazil      Bicho de Sete Cabeças             P495          Brazil          True
#             Desejos de Mulher                 P495          Brazil          True
#             Mulheres de Areia                 P495          Brazil          True
#             O Quatrilho                       P495          Brazil          True
# Cuba        Suite Habana                      P495          Cuba            True
# Denmark     Lise Ringheim                     P27           Denmark         True
# Egypt       Ayyam El Sadat                    P495          Egypt           True
# England     association football              P495          England         True
# Finland     Suomen Kuvalehti                  P495          Finland         True
# Florence    Salvatore Ferragamo Italia S.p.A. P740          Florence        True
# Indonesia   Evan Dimas Darmono                P27           Indonesia       True
# Ireland     John Banim                        P27           Ireland         True
#             Robert Erskine Childers           P27           Ireland         True
# Italy       Lupo Alberto                      P495          Italy           True
#             The Mattei Affair                 P495          Italy           True
# Jamaica     reggae                            P495          Jamaica         True
# Japan       Bandai Channel                    P740          Japan           True
#             Genma Taisen                      P495          Japan           True
#             Great Dangaioh                    P495          Japan           True
#             Magne Robo Gakeen                 P495          Japan           True
#             Mezamashi TV                      P495          Japan           True
#             Sonic Soldier Borgman             P495          Japan           True
#             matcha                            P495          Japan           True
# Mexico      La Hija del Jardinero             P495          Mexico          True
# Michigan    Lansing                           P1376         Michigan        True
# Moldova     Vasile Stati                      P27           Mold            True
# Norway      Bukkene Bruse                     P495          Norway          True
#             Dagsavisen                        P495          Norway          True
# Poland      Bezimienni bohaterowie            P495          Poland          True
#             Brzydula                          P495          Poland          True
#             Newsweek Polska                   P495          Poland          True
#             Polityka                          P495          Poland          True
#             Prokurator Alicja Horn            P495          Poland          True
#             Taniec z gwiazdami                P495          Poland          True
# Shanghai    Mingxing Film Company             P740          Shanghai        True
# Singapore   Howe Yoon Chong                   P27           Singapore       True
# Spain       Lucas de Tuy                      P27           Spain           True
# Sweden      Nyhetsmorgon                      P495          Sweden          True
#             Sven-Ingvars                      P495          Sweden          True
#             Uppdrag granskning                P495          Sweden          True
# Switzerland Auguste Forel                     P27           Switzerland     True
# Wales       Y Cymro                           P495          Wales           True
# Zimbabwe    Patrick Chinamasa                 P27           Zimbabwe        True
# chemistry   Italian Chemical Society          P101          chemistry       True
#
#                                                                          surface_pred  \
# obj_label   sub_label                         predicate_id answers
# Australia   Sydney Twelve                     P495          Australia           False
#             The Early Bird Show               P495          Australia           False
# Barcelona   Institut d'Estudis Catalans       P740          Barcelona           False
# Brazil      Bicho de Sete Cabeças             P495          Brazil              False
#             Desejos de Mulher                 P495          Brazil              False
#             Mulheres de Areia                 P495          Brazil              False
#             O Quatrilho                       P495          Brazil              False
# Cuba        Suite Habana                      P495          Cuba                False
# Denmark     Lise Ringheim                     P27           Denmark             False
# Egypt       Ayyam El Sadat                    P495          Egypt               False
# England     association football              P495          England             False
# Finland     Suomen Kuvalehti                  P495          Finland             False
# Florence    Salvatore Ferragamo Italia S.p.A. P740          Florence            False
# Indonesia   Evan Dimas Darmono                P27           Indonesia           False
# Ireland     John Banim                        P27           Ireland             False
#             Robert Erskine Childers           P27           Ireland             False
# Italy       Lupo Alberto                      P495          Italy               False
#             The Mattei Affair                 P495          Italy               False
# Jamaica     reggae                            P495          Jamaica             False
# Japan       Bandai Channel                    P740          Japan               False
#             Genma Taisen                      P495          Japan               False
#             Great Dangaioh                    P495          Japan               False
#             Magne Robo Gakeen                 P495          Japan               False
#             Mezamashi TV                      P495          Japan               False
#             Sonic Soldier Borgman             P495          Japan               False
#             matcha                            P495          Japan               False
# Mexico      La Hija del Jardinero             P495          Mexico              False
# Michigan    Lansing                           P1376         Michigan            False
# Moldova     Vasile Stati                      P27           Mold                False
# Norway      Bukkene Bruse                     P495          Norway              False
#             Dagsavisen                        P495          Norway              False
# Poland      Bezimienni bohaterowie            P495          Poland              False
#             Brzydula                          P495          Poland              False
#             Newsweek Polska                   P495          Poland              False
#             Polityka                          P495          Poland              False
#             Prokurator Alicja Horn            P495          Poland              False
#             Taniec z gwiazdami                P495          Poland              False
# Shanghai    Mingxing Film Company             P740          Shanghai            False
# Singapore   Howe Yoon Chong                   P27           Singapore           False
# Spain       Lucas de Tuy                      P27           Spain               False
# Sweden      Nyhetsmorgon                      P495          Sweden              False
#             Sven-Ingvars                      P495          Sweden              False
#             Uppdrag granskning                P495          Sweden              False
# Switzerland Auguste Forel                     P27           Switzerland         False
# Wales       Y Cymro                           P495          Wales               False
# Zimbabwe    Patrick Chinamasa                 P27           Zimbabwe            False
# chemistry   Italian Chemical Society          P101          chemistry           False
#
#                                                                          consistency_counts  \
# obj_label   sub_label                         predicate_id answers
# Australia   Sydney Twelve                     P495          Australia                   6.0
#             The Early Bird Show               P495          Australia                   6.0
# Barcelona   Institut d'Estudis Catalans       P740          Barcelona                  11.0
# Brazil      Bicho de Sete Cabeças             P495          Brazil                      6.0
#             Desejos de Mulher                 P495          Brazil                      9.0
#             Mulheres de Areia                 P495          Brazil                      6.0
#             O Quatrilho                       P495          Brazil                      7.0
# Cuba        Suite Habana                      P495          Cuba                        8.0
# Denmark     Lise Ringheim                     P27           Denmark                     6.0
# Egypt       Ayyam El Sadat                    P495          Egypt                      16.0
# England     association football              P495          England                     7.0
# Finland     Suomen Kuvalehti                  P495          Finland                     6.0
# Florence    Salvatore Ferragamo Italia S.p.A. P740          Florence                    7.0
# Indonesia   Evan Dimas Darmono                P27           Indonesia                   7.0
# Ireland     John Banim                        P27           Ireland                     7.0
#             Robert Erskine Childers           P27           Ireland                     7.0
# Italy       Lupo Alberto                      P495          Italy                       7.0
#             The Mattei Affair                 P495          Italy                       9.0
# Jamaica     reggae                            P495          Jamaica                     9.0
# Japan       Bandai Channel                    P740          Japan                       8.0
#             Genma Taisen                      P495          Japan                       8.0
#             Great Dangaioh                    P495          Japan                       9.0
#             Magne Robo Gakeen                 P495          Japan                      13.0
#             Mezamashi TV                      P495          Japan                       6.0
#             Sonic Soldier Borgman             P495          Japan                       6.0
#             matcha                            P495          Japan                      10.0
# Mexico      La Hija del Jardinero             P495          Mexico                      7.0
# Michigan    Lansing                           P1376         Michigan                    6.0
# Moldova     Vasile Stati                      P27           Mold                        6.0
# Norway      Bukkene Bruse                     P495          Norway                      8.0
#             Dagsavisen                        P495          Norway                      6.0
# Poland      Bezimienni bohaterowie            P495          Poland                      6.0
#             Brzydula                          P495          Poland                      7.0
#             Newsweek Polska                   P495          Poland                     12.0
#             Polityka                          P495          Poland                      8.0
#             Prokurator Alicja Horn            P495          Poland                      9.0
#             Taniec z gwiazdami                P495          Poland                     11.0
# Shanghai    Mingxing Film Company             P740          Shanghai                   12.0
# Singapore   Howe Yoon Chong                   P27           Singapore                   6.0
# Spain       Lucas de Tuy                      P27           Spain                       6.0
# Sweden      Nyhetsmorgon                      P495          Sweden                      7.0
#             Sven-Ingvars                      P495          Sweden                      7.0
#             Uppdrag granskning                P495          Sweden                      9.0
# Switzerland Auguste Forel                     P27           Switzerland                 6.0
# Wales       Y Cymro                           P495          Wales                       6.0
# Zimbabwe    Patrick Chinamasa                 P27           Zimbabwe                    6.0
# chemistry   Italian Chemical Society          P101          chemistry                   6.0
#
#                                                                          confident
# obj_label   sub_label                         predicate_id answers
# Australia   Sydney Twelve                     P495          Australia         True
#             The Early Bird Show               P495          Australia         True
# Barcelona   Institut d'Estudis Catalans       P740          Barcelona         True
# Brazil      Bicho de Sete Cabeças             P495          Brazil            True
#             Desejos de Mulher                 P495          Brazil            True
#             Mulheres de Areia                 P495          Brazil            True
#             O Quatrilho                       P495          Brazil            True
# Cuba        Suite Habana                      P495          Cuba              True
# Denmark     Lise Ringheim                     P27           Denmark           True
# Egypt       Ayyam El Sadat                    P495          Egypt             True
# England     association football              P495          England           True
# Finland     Suomen Kuvalehti                  P495          Finland           True
# Florence    Salvatore Ferragamo Italia S.p.A. P740          Florence          True
# Indonesia   Evan Dimas Darmono                P27           Indonesia         True
# Ireland     John Banim                        P27           Ireland           True
#             Robert Erskine Childers           P27           Ireland           True
# Italy       Lupo Alberto                      P495          Italy             True
#             The Mattei Affair                 P495          Italy             True
# Jamaica     reggae                            P495          Jamaica           True
# Japan       Bandai Channel                    P740          Japan             True
#             Genma Taisen                      P495          Japan             True
#             Great Dangaioh                    P495          Japan             True
#             Magne Robo Gakeen                 P495          Japan             True
#             Mezamashi TV                      P495          Japan             True
#             Sonic Soldier Borgman             P495          Japan             True
#             matcha                            P495          Japan             True
# Mexico      La Hija del Jardinero             P495          Mexico            True
# Michigan    Lansing                           P1376         Michigan          True
# Moldova     Vasile Stati                      P27           Mold              True
# Norway      Bukkene Bruse                     P495          Norway            True
#             Dagsavisen                        P495          Norway            True
# Poland      Bezimienni bohaterowie            P495          Poland            True
#             Brzydula                          P495          Poland            True
#             Newsweek Polska                   P495          Poland            True
#             Polityka                          P495          Poland            True
#             Prokurator Alicja Horn            P495          Poland            True
#             Taniec z gwiazdami                P495          Poland            True
# Shanghai    Mingxing Film Company             P740          Shanghai          True
# Singapore   Howe Yoon Chong                   P27           Singapore         True
# Spain       Lucas de Tuy                      P27           Spain             True
# Sweden      Nyhetsmorgon                      P495          Sweden            True
#             Sven-Ingvars                      P495          Sweden            True
#             Uppdrag granskning                P495          Sweden            True
# Switzerland Auguste Forel                     P27           Switzerland       True
# Wales       Y Cymro                           P495          Wales             True
# Zimbabwe    Patrick Chinamasa                 P27           Zimbabwe          True
# chemistry   Italian Chemical Society          P101          chemistry         True

# %% [markdown]
# ### Exact fact recall set
# We here save the exact fact recall samples.

# %% [markdown]
# We only keep entries in the exact fact recall set for which the popularity score (average monthly Wikipedia views) is above 1000.

# %%
pop_confident_fact_recall_preds = confident_fact_recall_preds[confident_fact_recall_preds.sub_view_rates>1000]
pop_confident_fact_recall_preds
# Out:
#              obj_label               sub_label predicate_id    source  \
# 17306   Constantinople               Procopius          P20  TREx_UHN
# 17309   Constantinople               Procopius          P20  TREx_UHN
# 17312   Constantinople               Procopius          P20  TREx_UHN
# 17317   Constantinople               Procopius          P20  TREx_UHN
# 17324   Constantinople               Procopius          P20  TREx_UHN
# ...                ...                     ...          ...       ...
# 165341         Galicia  Santiago de Compostela        P1376  TREx_UHN
# 165342         Galicia  Santiago de Compostela        P1376  TREx_UHN
# 165345         Galicia  Santiago de Compostela        P1376  TREx_UHN
# 165349         Galicia  Santiago de Compostela        P1376  TREx_UHN
# 165352         Galicia  Santiago de Compostela        P1376  TREx_UHN
#
#                                                    prompt  \
# 17306                                   Procopius died in
# 17309                                   Procopius died at
# 17312                            Procopius passed away in
# 17317                                Procopius expired at
# 17324                           Procopius's life ended in
# ...                                                   ...
# 165341      Santiago de Compostela is the capital city of
# 165342             Santiago de Compostela, the capital of
# 165345        Santiago de Compostela, the capital city of
# 165349     Santiago de Compostela, that is the capital of
# 165352  Santiago de Compostela, that is the capital ci...
#
#                                     template  sub_view_rates  obj_view_rates  \
# 17306                        [X] died in [Y]     9059.583333   109764.416667
# 17309                        [X] died at [Y]     9059.583333   109764.416667
# 17312                 [X] passed away in [Y]     9059.583333   109764.416667
# 17317                     [X] expired at [Y]     9059.583333   109764.416667
# 17324                [X]'s life ended in [Y]     9059.583333   109764.416667
# ...                                      ...             ...             ...
# 165341        [X] is the capital city of [Y]    28000.000000     2412.250000
# 165342               [X], the capital of [Y]    28000.000000     2412.250000
# 165345          [X], the capital city of [Y]    28000.000000     2412.250000
# 165349       [X], that is the capital of [Y]    28000.000000     2412.250000
# 165352  [X], that is the capital city of [Y]    28000.000000     2412.250000
#
#             answers  p_answers  ...  string_match  person_name  \
# 17306    Constantin   0.044890  ...         False        False
# 17309    Constantin   0.128613  ...         False        False
# 17312    Constantin   0.070805  ...         False        False
# 17317    Constantin   0.193499  ...         False        False
# 17324    Constantin   0.069759  ...         False        False
# ...             ...        ...  ...           ...          ...
# 165341          Gal   0.139605  ...         False        False
# 165342          Gal   0.501965  ...         False        False
# 165345          Gal   0.540636  ...         False        False
# 165349          Gal   0.342240  ...         False        False
# 165352          Gal   0.394213  ...         False        False
#
#                            used_template prompt_bias  strict_correct  \
# 17306                        [X] died in       False           False
# 17309                        [X] died at       False           False
# 17312                 [X] passed away in       False           False
# 17317                     [X] expired at       False           False
# 17324                [X]'s life ended in       False           False
# ...                                  ...         ...             ...
# 165341        [X] is the capital city of       False           False
# 165342               [X], the capital of       False           False
# 165345          [X], the capital city of       False           False
# 165349       [X], that is the capital of       False           False
# 165352  [X], that is the capital city of       False           False
#
#         first_token_correct  correct  surface_pred  consistency_counts  \
# 17306                  True     True         False                   6
# 17309                  True     True         False                   6
# 17312                  True     True         False                   6
# 17317                  True     True         False                   6
# 17324                  True     True         False                   6
# ...                     ...      ...           ...                 ...
# 165341                 True     True         False                   6
# 165342                 True     True         False                   6
# 165345                 True     True         False                   6
# 165349                 True     True         False                   6
# 165352                 True     True         False                   6
#
#         confident
# 17306        True
# 17309        True
# 17312        True
# 17317        True
# 17324        True
# ...           ...
# 165341       True
# 165342       True
# 165345       True
# 165349       True
# 165352       True
#
# [3072 rows x 21 columns]

# %% [markdown]
# The predictions are generally quite confident.

# %%
pop_confident_fact_recall_preds.p_answers.mean()
# Out:
# 0.27611644265738855

# %%
pop_confident_fact_recall_preds.rank_answers.value_counts()
# Out:
# 1    1049
# 2    1033
# 0     990
# Name: rank_answers, dtype: int64

# %% [markdown]
# Save the data

# %%
pop_confident_fact_recall_preds.to_json(os.path.join(SAVEFOLDER, "exact_fact_recall_set.jsonl"), lines=True, orient="records")

# %% [markdown]
# ### Random guesswork set
#
# We here save the random guesswork samples. These are samples that are correct but inconsistent.

# %%
gold_label_set = data.obj_label.unique()
answer_is_in_gold_label_set = data.answers.apply(lambda val: val.strip() in gold_label_set)
random_guesswork_set = data[(data.consistency_counts<2) & 
                            (answer_is_in_gold_label_set) &
                            (data.sub_view_rates<1000)
                           ].copy()
random_guesswork_set
# Out:
#         obj_label             sub_label predicate_id         source  \
# 32       Scotland          Paul Mounsey          P19       TREx_UHN
# 77          Paris         Claude Arrieu          P19       TREx_UHN
# 79          Paris         Claude Arrieu          P19       TREx_UHN
# 125     Barcelona           Henry Heras          P19       TREx_UHN
# 136          Rome  Daniele Franceschini          P19       TREx_UHN
# ...           ...                   ...          ...            ...
# 226456     Moscow    Nikolay Strunnikov          P20  Google_RE_UHN
# 226480     Quebec        Claude Aveneau          P20  Google_RE_UHN
# 226505     Venice      Raffaele Venusti          P20  Google_RE_UHN
# 226935    Beverly         Arne Brun Lie          P20  Google_RE_UHN
# 227656   Shanghai           Fu Zhongwen          P20  Google_RE_UHN
#
#                                    prompt                    template  \
# 32               Paul Mounsey was born in         [X] was born in [Y]
# 77              Claude Arrieu was born in         [X] was born in [Y]
# 79       Claude Arrieu is originally from  [X] is originally from [Y]
# 125        Henry Heras is originally from  [X] is originally from [Y]
# 136      Daniele Franceschini was born in         [X] was born in [Y]
# ...                                   ...                         ...
# 226456  Nikolay Strunnikov passed away in      [X] passed away in [Y]
# 226480      Claude Aveneau passed away in      [X] passed away in [Y]
# 226505    Raffaele Venusti passed away in      [X] passed away in [Y]
# 226935       Arne Brun Lie passed away in      [X] passed away in [Y]
# 227656         Fu Zhongwen passed away in      [X] passed away in [Y]
#
#         sub_view_rates  obj_view_rates    answers  p_answers  ...  \
# 32          313.750000   259042.083333     London   0.038695  ...
# 77          342.750000   227647.083333      Paris   0.057988  ...
# 79          342.750000   227647.083333     France   0.074929  ...
# 125         306.500000   156304.833333     Mexico   0.039514  ...
# 136         205.250000   166365.083333   Florence   0.072317  ...
# ...                ...             ...        ...        ...  ...
# 226456       82.916667   130953.583333     Moscow   0.127888  ...
# 226480       63.416667   120671.000000      Paris   0.139089  ...
# 226505       40.083333   136078.083333       Rome   0.053666  ...
# 226935       72.500000     1624.416667       Oslo   0.277760  ...
# 227656      312.750000   132321.333333    Beijing   0.080153  ...
#
#         string_match  person_name           used_template prompt_bias  \
# 32             False         True         [X] was born in        True
# 77             False         True         [X] was born in        True
# 79             False         True  [X] is originally from       False
# 125            False        False  [X] is originally from       False
# 136            False        False         [X] was born in       False
# ...              ...          ...                     ...         ...
# 226456         False        False      [X] passed away in       False
# 226480         False         True      [X] passed away in       False
# 226505         False         True      [X] passed away in       False
# 226935         False        False      [X] passed away in       False
# 227656         False         True      [X] passed away in       False
#
#         strict_correct  first_token_correct  correct  surface_pred  \
# 32               False                False    False          True
# 77                True                 True     True          True
# 79               False                False    False          True
# 125              False                False    False         False
# 136              False                False    False         False
# ...                ...                  ...      ...           ...
# 226456            True                 True     True         False
# 226480           False                False    False          True
# 226505           False                False    False          True
# 226935           False                False    False         False
# 227656           False                False    False          True
#
#         consistency_counts  confident
# 32                       1      False
# 77                       1      False
# 79                       1      False
# 125                      1      False
# 136                      1      False
# ...                    ...        ...
# 226456                   1      False
# 226480                   1      False
# 226505                   1      False
# 226935                   1      False
# 227656                   1      False
#
# [3859 rows x 21 columns]

# %%
random_guesswork_set.rank_answers.value_counts()
# Out:
# 2    2854
# 1     923
# 0     593
# Name: rank_answers, dtype: int64

# %%
random_guesswork_set.p_answers.mean()
# Out:
# 0.04057559630709405

# %%
random_guesswork_set.rank_answers.value_counts()
# Out:
# 2    2854
# 1     923
# 0     593
# Name: rank_answers, dtype: int64

# %%
random_guesswork_set.correct.value_counts()
# Out:
# False    3846
# True      524
# Name: correct, dtype: int64

# %% [markdown]
# Save the data

# %%
random_guesswork_set.to_json(os.path.join(SAVEFOLDER, "random_guesswork_set.jsonl"), lines=True, orient="records")
